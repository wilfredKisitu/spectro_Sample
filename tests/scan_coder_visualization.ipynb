# %% [markdown]
# ## Scan Coder Spectral Visualization

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



data_path = "../spectral_data"
DEVICE_CODE = 'Scan coder'
DEVICE_CODE_2 = 'Scancorder'

# %% [markdown]
# ## Sample Dataloading

# %%
_listdir = lambda _dir: os.listdir(_dir)
join_path = lambda paranet_dir, child_dir: os.path.join(paranet_dir, child_dir)

for week in _listdir(data_path):
    week_dir = join_path(data_path, week)
    for device in _listdir(week_dir):
        if device == DEVICE_CODE or device == DEVICE_CODE_2:
            device_dir = join_path(week_dir, device)
            for sub_dir in _listdir(device_dir):
                print(sub_dir)
        else:
            continue
# Out:
# 2026-03-15T21-41-24-461_week3_prediction_table.csv
# beans3
# cassava3
# maize3
# 2026-02-26T08-13-34-144_All-data-1_prediction_table.csv
# beans1
# cassava1
# 2026-02-26T08-15-01-606_maizecs-data_prediction_table.csv
# maize1
# 2026-02-26T08-18-03-265_export-table_prediction_table.csv
# 2026-02-26T08-16-08-148_beanscs-data_prediction_table.csv
# 2026-03-29T13-03-38-231_Week-5-scancorder_prediction_table.csv
# Beans2
# maize2
# cassava2

# %% [markdown]
# ## Initail Folder Organization Required
